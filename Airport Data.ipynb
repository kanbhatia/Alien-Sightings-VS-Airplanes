# %%
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd

# %%
base = "https://v4p4sz5ijk.execute-api.us-east-1.amazonaws.com/anbdata/airports/traffic/departure-stats?api_key=1d820730-a43a-11e9-8ba5-19b2d1f43f82&airports=&states=CAN&format=json&Year="


#print(requests.get(base).json())
#response = requests.get(base).json()
#print(json.dumps(response, indent=4, sort_keys=True))

response = requests.get(base)
print(response.url)
# Out:
# https://v4p4sz5ijk.execute-api.us-east-1.amazonaws.com/anbdata/airports/traffic/departure-stats?api_key=1d820730-a43a-11e9-8ba5-19b2d1f43f82&airports=&states=CAN&format=json&Year=

# %%
data = response.json()
pprint(data)
# Out:
# [{'Airport': 'CYWP',
#   'AirportName': 'WEBEQUIE',
#   'Connections': 4,
#   'Departures': 365,
#   'Domestic': 365,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYTL',
#   'AirportName': 'BIG TROUT LAKE',
#   'Connections': 6,
#   'Departures': 863,
#   'Domestic': 863,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYPL',
#   'AirportName': 'PICKLE LAKE',
#   'Connections': 5,
#   'Departures': 626,
#   'Domestic': 626,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZMD',
#   'AirportName': 'MUSKRAT DAM',
#   'Connections': 4,
#   'Departures': 488,
#   'Domestic': 488,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYKF',
#   'AirportName': 'KITCHENER',
#   'Connections': 1,
#   'Departures': 355,
#   'Domestic': 355,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYBR',
#   'AirportName': 'BRANDON',
#   'Connections': 1,
#   'Departures': 497,
#   'Domestic': 497,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZFD',
#   'AirportName': 'FOND DU LAC',
#   'Connections': 3,
#   'Departures': 21,
#   'Domestic': 21,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYSF',
#   'AirportName': 'STONY RAPIDS',
#   'Connections': 2,
#   'Departures': 12,
#   'Domestic': 12,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYNL',
#   'AirportName': 'POINTS NORTH LAND',
#   'Connections': 2,
#   'Departures': 11,
#   'Domestic': 11,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYBE',
#   'AirportName': 'URANIUM CITY',
#   'Connections': 1,
#   'Departures': 6,
#   'Domestic': 6,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYFT',
#   'AirportName': 'MAKKOVIK',
#   'Connections': 2,
#   'Departures': 624,
#   'Domestic': 624,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYHO',
#   'AirportName': 'HOPEDALE',
#   'Connections': 3,
#   'Departures': 625,
#   'Domestic': 625,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYCL',
#   'AirportName': 'CHARLO',
#   'Connections': 4,
#   'Departures': 319,
#   'Domestic': 319,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAY',
#   'AirportName': 'ST ANTHONY',
#   'Connections': 5,
#   'Departures': 716,
#   'Domestic': 716,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYVB',
#   'AirportName': 'BONAVENTURE',
#   'Connections': 2,
#   'Departures': 1010,
#   'Domestic': 1010,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYHU',
#   'AirportName': 'ST HUBERT',
#   'Connections': 5,
#   'Departures': 1440,
#   'Domestic': 1435,
#   'DomesticConnections': 4,
#   'International': 5,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYJT',
#   'AirportName': 'STEPHENVILLE',
#   'Connections': 6,
#   'Departures': 170,
#   'Domestic': 170,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYPY',
#   'AirportName': 'FORT CHIPEWYAN',
#   'Connections': 2,
#   'Departures': 419,
#   'Domestic': 419,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZMT',
#   'AirportName': 'MASSET',
#   'Connections': 1,
#   'Departures': 256,
#   'Domestic': 256,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYJQ',
#   'AirportName': 'BELLA BELLA',
#   'Connections': 3,
#   'Departures': 665,
#   'Domestic': 665,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYZT',
#   'AirportName': 'PORT HARDY',
#   'Connections': 2,
#   'Departures': 1257,
#   'Domestic': 1257,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYPW',
#   'AirportName': 'POWELL RIVER',
#   'Connections': 1,
#   'Departures': 1838,
#   'Domestic': 1838,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYBD',
#   'AirportName': 'BELLA COOLA',
#   'Connections': 2,
#   'Departures': 477,
#   'Domestic': 477,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZFN',
#   'AirportName': 'FORT NORMAN',
#   'Connections': 2,
#   'Departures': 1409,
#   'Domestic': 1409,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYWJ',
#   'AirportName': 'FORT FRANKLIN',
#   'Connections': 2,
#   'Departures': 835,
#   'Domestic': 835,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAQ',
#   'AirportName': 'KASABONIKA',
#   'Connections': 6,
#   'Departures': 625,
#   'Domestic': 625,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYGH',
#   'AirportName': 'FORT GOOD HOPE',
#   'Connections': 5,
#   'Departures': 836,
#   'Domestic': 836,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYKD',
#   'AirportName': 'AKLAVIK',
#   'Connections': 1,
#   'Departures': 573,
#   'Domestic': 573,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYND',
#   'AirportName': 'GATINEAU',
#   'Connections': 1,
#   'Departures': 446,
#   'Domestic': 446,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYNA',
#   'AirportName': 'NATASHQUAN',
#   'Connections': 5,
#   'Departures': 1309,
#   'Domestic': 1309,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYHR',
#   'AirportName': 'CHEVERY',
#   'Connections': 9,
#   'Departures': 1845,
#   'Domestic': 1845,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYVQ',
#   'AirportName': 'NORMAN WELLS',
#   'Connections': 5,
#   'Departures': 1716,
#   'Domestic': 1716,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYGB',
#   'AirportName': 'GILLIES BAY',
#   'Connections': 2,
#   'Departures': 1170,
#   'Domestic': 1170,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAZ',
#   'AirportName': 'TOFINO',
#   'Connections': 2,
#   'Departures': 1290,
#   'Domestic': 1290,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYGZ',
#   'AirportName': 'GRISE FIORD',
#   'Connections': 1,
#   'Departures': 104,
#   'Domestic': 104,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQZ',
#   'AirportName': 'QUESNEL',
#   'Connections': 2,
#   'Departures': 672,
#   'Domestic': 672,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYOJ',
#   'AirportName': 'HIGH LEVEL',
#   'Connections': 4,
#   'Departures': 1032,
#   'Domestic': 1032,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYLL',
#   'AirportName': 'LLOYDMINSTER',
#   'Connections': 2,
#   'Departures': 361,
#   'Domestic': 361,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYDL',
#   'AirportName': 'DEASE LAKE',
#   'Connections': 1,
#   'Departures': 12,
#   'Domestic': 12,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYYH',
#   'AirportName': 'TALOYAK',
#   'Connections': 6,
#   'Departures': 541,
#   'Domestic': 541,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYXP',
#   'AirportName': 'PANGNIRTUNG',
#   'Connections': 5,
#   'Departures': 1084,
#   'Domestic': 1084,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYVM',
#   'AirportName': 'BROUGHTON ISLAND',
#   'Connections': 4,
#   'Departures': 435,
#   'Domestic': 435,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYUX',
#   'AirportName': 'HALL BEACH',
#   'Connections': 5,
#   'Departures': 720,
#   'Domestic': 720,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYSM',
#   'AirportName': 'FORT SMITH',
#   'Connections': 6,
#   'Departures': 1307,
#   'Domestic': 1307,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYRB',
#   'AirportName': 'RESOLUTE',
#   'Connections': 4,
#   'Departures': 499,
#   'Domestic': 499,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYHY',
#   'AirportName': 'HAY RIVER',
#   'Connections': 5,
#   'Departures': 1203,
#   'Domestic': 1203,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYHK',
#   'AirportName': 'GJOA HAVEN',
#   'Connections': 8,
#   'Departures': 545,
#   'Domestic': 545,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYFS',
#   'AirportName': 'FORT SIMPSON',
#   'Connections': 2,
#   'Departures': 624,
#   'Domestic': 624,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYFB',
#   'AirportName': 'IQALUIT',
#   'Connections': 22,
#   'Departures': 4110,
#   'Domestic': 4109,
#   'DomesticConnections': 21,
#   'International': 1,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYCY',
#   'AirportName': 'CLYDE RIVER',
#   'Connections': 5,
#   'Departures': 384,
#   'Domestic': 384,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYCO',
#   'AirportName': 'COPPERMINE',
#   'Connections': 5,
#   'Departures': 675,
#   'Domestic': 675,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYPO',
#   'AirportName': 'PEAWANUCK',
#   'Connections': 1,
#   'Departures': 104,
#   'Domestic': 104,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYMT',
#   'AirportName': 'CHIBOUGAMAU',
#   'Connections': 3,
#   'Departures': 567,
#   'Domestic': 567,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAT',
#   'AirportName': 'ATTAWAPISKAT',
#   'Connections': 3,
#   'Departures': 643,
#   'Domestic': 643,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYXN',
#   'AirportName': 'WHALE COVE',
#   'Connections': 2,
#   'Departures': 730,
#   'Domestic': 730,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYUT',
#   'AirportName': 'REPULSE BAY',
#   'Connections': 4,
#   'Departures': 630,
#   'Domestic': 630,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYRT',
#   'AirportName': 'RANKIN INLET',
#   'Connections': 12,
#   'Departures': 2764,
#   'Domestic': 2764,
#   'DomesticConnections': 12,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQR',
#   'AirportName': 'REGINA',
#   'Connections': 18,
#   'Departures': 8806,
#   'Domestic': 8042,
#   'DomesticConnections': 14,
#   'International': 764,
#   'InternationalConnections': 4,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYBK',
#   'AirportName': 'BAKER LAKE',
#   'Connections': 2,
#   'Departures': 678,
#   'Domestic': 678,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYDA',
#   'AirportName': 'DAWSON CITY',
#   'Connections': 4,
#   'Departures': 902,
#   'Domestic': 902,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYRT',
#   'AirportName': 'RANKIN INLET',
#   'Connections': 17,
#   'Departures': 2722,
#   'Domestic': 2722,
#   'DomesticConnections': 17,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYQH',
#   'AirportName': 'WATSON LAKE',
#   'Connections': 1,
#   'Departures': 85,
#   'Domestic': 85,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYEV',
#   'AirportName': 'INUVIK',
#   'Connections': 13,
#   'Departures': 3411,
#   'Domestic': 3411,
#   'DomesticConnections': 13,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYYB',
#   'AirportName': 'NORTH BAY',
#   'Connections': 5,
#   'Departures': 2544,
#   'Domestic': 2544,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYZS',
#   'AirportName': 'CORAL HARBOUR',
#   'Connections': 3,
#   'Departures': 631,
#   'Domestic': 631,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZRJ',
#   'AirportName': 'ROUND LAKE, OT',
#   'Connections': 9,
#   'Departures': 649,
#   'Domestic': 649,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYZG',
#   'AirportName': 'SALLUIT',
#   'Connections': 5,
#   'Departures': 784,
#   'Domestic': 784,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYTE',
#   'AirportName': 'CAPE DORSET',
#   'Connections': 5,
#   'Departures': 553,
#   'Domestic': 553,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYBT',
#   'AirportName': 'BROCHET',
#   'Connections': 2,
#   'Departures': 365,
#   'Domestic': 365,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYMT',
#   'AirportName': 'CHIBOUGAMAU',
#   'Connections': 2,
#   'Departures': 558,
#   'Domestic': 558,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYKL',
#   'AirportName': 'SCHEFFERVILLE',
#   'Connections': 4,
#   'Departures': 1091,
#   'Domestic': 1091,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAS',
#   'AirportName': 'KANGIRSUK',
#   'Connections': 3,
#   'Departures': 1038,
#   'Domestic': 1038,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYIK',
#   'AirportName': 'IVUJIVIK',
#   'Connections': 2,
#   'Departures': 722,
#   'Domestic': 722,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYLU',
#   'AirportName': 'KANGIQSUALUJJUAQ',
#   'Connections': 2,
#   'Departures': 626,
#   'Domestic': 626,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZTM',
#   'AirportName': 'SHAMATTAWA',
#   'Connections': 6,
#   'Departures': 661,
#   'Domestic': 661,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZSJ',
#   'AirportName': 'SANDY LAKE',
#   'Connections': 14,
#   'Departures': 2371,
#   'Domestic': 2371,
#   'DomesticConnections': 14,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZRJ',
#   'AirportName': 'ROUND LAKE, OT',
#   'Connections': 12,
#   'Departures': 1133,
#   'Domestic': 1133,
#   'DomesticConnections': 12,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZPB',
#   'AirportName': 'SACHIGO LAKE',
#   'Connections': 13,
#   'Departures': 1108,
#   'Domestic': 1108,
#   'DomesticConnections': 13,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZAC',
#   'AirportName': 'YORK LANDING',
#   'Connections': 2,
#   'Departures': 261,
#   'Domestic': 261,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYPM',
#   'AirportName': 'PIKANGIKUM',
#   'Connections': 13,
#   'Departures': 1808,
#   'Domestic': 1808,
#   'DomesticConnections': 13,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYKO',
#   'AirportName': 'AKULIVIK',
#   'Connections': 2,
#   'Departures': 732,
#   'Domestic': 732,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2012},
#  {'Airport': 'CYNE',
#   'AirportName': 'NORWAY HOUSE',
#   'Connections': 4,
#   'Departures': 1050,
#   'Domestic': 1050,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYGL',
#   'AirportName': 'LA GRANDE',
#   'Connections': 4,
#   'Departures': 894,
#   'Domestic': 894,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYXP',
#   'AirportName': 'PANGNIRTUNG',
#   'Connections': 4,
#   'Departures': 1242,
#   'Domestic': 1242,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYIV',
#   'AirportName': 'ISLAND LAKE/GARDEN HILL',
#   'Connections': 6,
#   'Departures': 1432,
#   'Domestic': 1432,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAC',
#   'AirportName': 'CAT LAKE',
#   'Connections': 6,
#   'Departures': 477,
#   'Domestic': 477,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYEG',
#   'AirportName': 'EDMONTON INTL',
#   'Connections': 98,
#   'Departures': 48439,
#   'Domestic': 39399,
#   'DomesticConnections': 51,
#   'International': 9040,
#   'InternationalConnections': 47,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2014},
#  {'Airport': 'CZSN',
#   'AirportName': 'SOUTH INDIAN LAKE',
#   'Connections': 2,
#   'Departures': 313,
#   'Domestic': 313,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZWH',
#   'AirportName': 'LAC BROCHET',
#   'Connections': 6,
#   'Departures': 626,
#   'Domestic': 626,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYZR',
#   'AirportName': 'SARNIA',
#   'Connections': 1,
#   'Departures': 1375,
#   'Domestic': 1375,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYZV',
#   'AirportName': 'SEPT ILES',
#   'Connections': 22,
#   'Departures': 6832,
#   'Domestic': 6832,
#   'DomesticConnections': 22,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYZP',
#   'AirportName': 'SANDSPIT',
#   'Connections': 1,
#   'Departures': 458,
#   'Domestic': 458,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYYT',
#   'AirportName': "ST JOHN'S",
#   'Connections': 33,
#   'Departures': 12818,
#   'Domestic': 12170,
#   'DomesticConnections': 23,
#   'International': 648,
#   'InternationalConnections': 10,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZMT',
#   'AirportName': 'MASSET',
#   'Connections': 1,
#   'Departures': 346,
#   'Domestic': 346,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYYD',
#   'AirportName': 'SMITHERS',
#   'Connections': 3,
#   'Departures': 1117,
#   'Domestic': 1117,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYYH',
#   'AirportName': 'TALOYAK',
#   'Connections': 8,
#   'Departures': 545,
#   'Domestic': 545,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2015},
#  {'Airport': 'CZGI',
#   'AirportName': 'GODS RIVER',
#   'Connections': 2,
#   'Departures': 628,
#   'Domestic': 628,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYYR',
#   'AirportName': 'GOOSE BAY',
#   'Connections': 17,
#   'Departures': 4705,
#   'Domestic': 4705,
#   'DomesticConnections': 17,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYXT',
#   'AirportName': 'TERRACE',
#   'Connections': 6,
#   'Departures': 2442,
#   'Domestic': 2442,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYTL',
#   'AirportName': 'BIG TROUT LAKE',
#   'Connections': 5,
#   'Departures': 693,
#   'Domestic': 693,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2014},
#  {'Airport': 'CYVO',
#   'AirportName': "VAL D'OR",
#   'Connections': 10,
#   'Departures': 3073,
#   'Domestic': 3073,
#   'DomesticConnections': 10,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYUY',
#   'AirportName': 'ROUYN',
#   'Connections': 9,
#   'Departures': 2912,
#   'Domestic': 2912,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQQ',
#   'AirportName': 'COMOX',
#   'Connections': 9,
#   'Departures': 4610,
#   'Domestic': 4586,
#   'DomesticConnections': 8,
#   'International': 24,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAZ',
#   'AirportName': 'TOFINO',
#   'Connections': 1,
#   'Departures': 151,
#   'Domestic': 151,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYKA',
#   'AirportName': 'KAMLOOPS',
#   'Connections': 8,
#   'Departures': 4057,
#   'Domestic': 4057,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYBV',
#   'AirportName': 'BERENS RIVER',
#   'Connections': 3,
#   'Departures': 303,
#   'Domestic': 303,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQU',
#   'AirportName': 'GRANDE PRAIRIE',
#   'Connections': 4,
#   'Departures': 4386,
#   'Domestic': 4386,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQM',
#   'AirportName': 'MONCTON',
#   'Connections': 20,
#   'Departures': 7885,
#   'Domestic': 7761,
#   'DomesticConnections': 11,
#   'International': 124,
#   'InternationalConnections': 9,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYMM',
#   'AirportName': 'FORT MCMURRAY',
#   'Connections': 8,
#   'Departures': 6425,
#   'Domestic': 6425,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYKA',
#   'AirportName': 'KAMLOOPS',
#   'Connections': 9,
#   'Departures': 4431,
#   'Domestic': 4431,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYWL',
#   'AirportName': 'WILLIAMS LAKE',
#   'Connections': 2,
#   'Departures': 1836,
#   'Domestic': 1836,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYGK',
#   'AirportName': 'KINGSTON',
#   'Connections': 1,
#   'Departures': 1674,
#   'Domestic': 1674,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYMH',
#   'AirportName': "MARY'S HARBOUR",
#   'Connections': 4,
#   'Departures': 219,
#   'Domestic': 219,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYGP',
#   'AirportName': 'GASPE',
#   'Connections': 2,
#   'Departures': 1458,
#   'Domestic': 1458,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYKQ',
#   'AirportName': 'WASKAGANISH',
#   'Connections': 5,
#   'Departures': 1292,
#   'Domestic': 1292,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYDF',
#   'AirportName': 'DEER LAKE',
#   'Connections': 14,
#   'Departures': 5317,
#   'Domestic': 5308,
#   'DomesticConnections': 13,
#   'International': 9,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYCG',
#   'AirportName': 'CASTLEGAR',
#   'Connections': 2,
#   'Departures': 1347,
#   'Domestic': 1347,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYAM',
#   'AirportName': 'SAULT STE-MARIE',
#   'Connections': 4,
#   'Departures': 4315,
#   'Domestic': 4315,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CZSN',
#   'AirportName': 'SOUTH INDIAN LAKE',
#   'Connections': 1,
#   'Departures': 40,
#   'Domestic': 40,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2015},
#  {'Airport': 'CYOW',
#   'AirportName': 'OTTAWA INTL',
#   'Connections': 78,
#   'Departures': 40076,
#   'Domestic': 31471,
#   'DomesticConnections': 37,
#   'International': 8605,
#   'InternationalConnections': 41,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYUL',
#   'AirportName': 'PIERRE ELLIOTT TRUDEAU INTL',
#   'Connections': 266,
#   'Departures': 103979,
#   'Domestic': 53291,
#   'DomesticConnections': 60,
#   'International': 50688,
#   'InternationalConnections': 206,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYQB',
#   'AirportName': 'JEAN LESAGE INTL',
#   'Connections': 51,
#   'Departures': 18709,
#   'Domestic': 16518,
#   'DomesticConnections': 26,
#   'International': 2191,
#   'InternationalConnections': 25,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYLH',
#   'AirportName': 'LANDSDOWNE HOUSE',
#   'Connections': 4,
#   'Departures': 257,
#   'Domestic': 257,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYER',
#   'AirportName': 'FORT SEVERN',
#   'Connections': 2,
#   'Departures': 314,
#   'Domestic': 314,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYVC',
#   'AirportName': 'LA RONGE',
#   'Connections': 4,
#   'Departures': 179,
#   'Domestic': 179,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYYE',
#   'AirportName': 'FORT NELSON',
#   'Connections': 3,
#   'Departures': 886,
#   'Domestic': 886,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYXU',
#   'AirportName': 'LONDON',
#   'Connections': 7,
#   'Departures': 6079,
#   'Domestic': 4640,
#   'DomesticConnections': 6,
#   'International': 1439,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYSJ',
#   'AirportName': 'ST JOHN',
#   'Connections': 5,
#   'Departures': 3887,
#   'Domestic': 3887,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYHZ',
#   'AirportName': 'HALIFAX',
#   'Connections': 83,
#   'Departures': 33543,
#   'Domestic': 27249,
#   'DomesticConnections': 38,
#   'International': 6294,
#   'InternationalConnections': 45,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYSF',
#   'AirportName': 'STONY RAPIDS',
#   'Connections': 4,
#   'Departures': 112,
#   'Domestic': 112,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZEM',
#   'AirportName': 'EASTMAIN',
#   'Connections': 2,
#   'Departures': 720,
#   'Domestic': 720,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2012},
#  {'Airport': 'CYNL',
#   'AirportName': 'POINTS NORTH LAND',
#   'Connections': 3,
#   'Departures': 48,
#   'Domestic': 48,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYXH',
#   'AirportName': 'MEDICINE HAT',
#   'Connections': 2,
#   'Departures': 1906,
#   'Domestic': 1906,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYCY',
#   'AirportName': 'CLYDE RIVER',
#   'Connections': 3,
#   'Departures': 568,
#   'Domestic': 568,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYVP',
#   'AirportName': 'KUUJJUAQ',
#   'Connections': 9,
#   'Departures': 2694,
#   'Domestic': 2694,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYOW',
#   'AirportName': 'OTTAWA INTL',
#   'Connections': 101,
#   'Departures': 46265,
#   'Domestic': 33467,
#   'DomesticConnections': 45,
#   'International': 12798,
#   'InternationalConnections': 56,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2012},
#  {'Airport': 'CYBE',
#   'AirportName': 'URANIUM CITY',
#   'Connections': 1,
#   'Departures': 24,
#   'Domestic': 24,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYCL',
#   'AirportName': 'CHARLO',
#   'Connections': 3,
#   'Departures': 347,
#   'Domestic': 347,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYJT',
#   'AirportName': 'STEPHENVILLE',
#   'Connections': 3,
#   'Departures': 218,
#   'Domestic': 218,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYBD',
#   'AirportName': 'BELLA COOLA',
#   'Connections': 2,
#   'Departures': 445,
#   'Domestic': 445,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZFN',
#   'AirportName': 'FORT NORMAN',
#   'Connections': 2,
#   'Departures': 1433,
#   'Domestic': 1433,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYWJ',
#   'AirportName': 'FORT FRANKLIN',
#   'Connections': 3,
#   'Departures': 1035,
#   'Domestic': 1035,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZMD',
#   'AirportName': 'MUSKRAT DAM',
#   'Connections': 4,
#   'Departures': 595,
#   'Domestic': 595,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYFT',
#   'AirportName': 'MAKKOVIK',
#   'Connections': 5,
#   'Departures': 955,
#   'Domestic': 955,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZWH',
#   'AirportName': 'LAC BROCHET',
#   'Connections': 2,
#   'Departures': 365,
#   'Domestic': 365,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CZWL',
#   'AirportName': 'WOLLASTON LAKE',
#   'Connections': 4,
#   'Departures': 804,
#   'Domestic': 804,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYVR',
#   'AirportName': 'VANCOUVER INTL',
#   'Connections': 178,
#   'Departures': 107733,
#   'Domestic': 74468,
#   'DomesticConnections': 78,
#   'International': 33265,
#   'InternationalConnections': 100,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2013},
#  {'Airport': 'CYEG',
#   'AirportName': 'EDMONTON INTL',
#   'Connections': 117,
#   'Departures': 43064,
#   'Domestic': 36303,
#   'DomesticConnections': 65,
#   'International': 6761,
#   'InternationalConnections': 52,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYAY',
#   'AirportName': 'ST ANTHONY',
#   'Connections': 8,
#   'Departures': 761,
#   'Domestic': 761,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYUX',
#   'AirportName': 'HALL BEACH',
#   'Connections': 3,
#   'Departures': 311,
#   'Domestic': 311,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CZSJ',
#   'AirportName': 'SANDY LAKE',
#   'Connections': 6,
#   'Departures': 562,
#   'Domestic': 562,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYAC',
#   'AirportName': 'CAT LAKE',
#   'Connections': 2,
#   'Departures': 540,
#   'Domestic': 540,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2010},
#  {'Airport': 'CYGB',
#   'AirportName': 'GILLIES BAY',
#   'Connections': 3,
#   'Departures': 1443,
#   'Domestic': 1443,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYTQ',
#   'AirportName': 'TASIUJUAQ',
#   'Connections': 2,
#   'Departures': 878,
#   'Domestic': 878,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYWL',
#   'AirportName': 'WILLIAMS LAKE',
#   'Connections': 3,
#   'Departures': 1784,
#   'Domestic': 1784,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYVM',
#   'AirportName': 'BROUGHTON ISLAND',
#   'Connections': 4,
#   'Departures': 376,
#   'Domestic': 376,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZMD',
#   'AirportName': 'MUSKRAT DAM',
#   'Connections': 6,
#   'Departures': 557,
#   'Domestic': 557,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYUX',
#   'AirportName': 'HALL BEACH',
#   'Connections': 4,
#   'Departures': 686,
#   'Domestic': 686,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYHK',
#   'AirportName': 'GJOA HAVEN',
#   'Connections': 7,
#   'Departures': 545,
#   'Domestic': 545,
#   'DomesticConnections': 7,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYCD',
#   'AirportName': 'NANAIMO ARPT',
#   'Connections': 5,
#   'Departures': 4629,
#   'Domestic': 4629,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYGT',
#   'AirportName': 'IGLOOLIK',
#   'Connections': 9,
#   'Departures': 774,
#   'Domestic': 774,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYFS',
#   'AirportName': 'FORT SIMPSON',
#   'Connections': 2,
#   'Departures': 622,
#   'Domestic': 622,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYDA',
#   'AirportName': 'DAWSON CITY',
#   'Connections': 3,
#   'Departures': 496,
#   'Domestic': 496,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2010},
#  {'Airport': 'CYFB',
#   'AirportName': 'IQALUIT',
#   'Connections': 20,
#   'Departures': 3719,
#   'Domestic': 3719,
#   'DomesticConnections': 20,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYCY',
#   'AirportName': 'CLYDE RIVER',
#   'Connections': 4,
#   'Departures': 344,
#   'Domestic': 344,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYHK',
#   'AirportName': 'GJOA HAVEN',
#   'Connections': 9,
#   'Departures': 730,
#   'Domestic': 730,
#   'DomesticConnections': 9,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2015},
#  {'Airport': 'CYCO',
#   'AirportName': 'COPPERMINE',
#   'Connections': 5,
#   'Departures': 677,
#   'Domestic': 677,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYCB',
#   'AirportName': 'CAMBRIDGE BAY',
#   'Connections': 7,
#   'Departures': 830,
#   'Domestic': 830,
#   'DomesticConnections': 7,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CZEM',
#   'AirportName': 'EASTMAIN',
#   'Connections': 2,
#   'Departures': 477,
#   'Domestic': 477,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYXL',
#   'AirportName': 'SIOUX LOOKOUT',
#   'Connections': 8,
#   'Departures': 2665,
#   'Domestic': 2665,
#   'DomesticConnections': 8,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYMT',
#   'AirportName': 'CHIBOUGAMAU',
#   'Connections': 3,
#   'Departures': 481,
#   'Domestic': 481,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYKQ',
#   'AirportName': 'WASKAGANISH',
#   'Connections': 4,
#   'Departures': 1040,
#   'Domestic': 1040,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYUB',
#   'AirportName': 'TUKTOYAKTUK',
#   'Connections': 1,
#   'Departures': 941,
#   'Domestic': 941,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYMX',
#   'AirportName': 'MIRABEL',
#   'Connections': 4,
#   'Departures': 1287,
#   'Domestic': 1287,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYAZ',
#   'AirportName': 'TOFINO',
#   'Connections': 1,
#   'Departures': 1294,
#   'Domestic': 1294,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYPO',
#   'AirportName': 'PEAWANUCK',
#   'Connections': 1,
#   'Departures': 103,
#   'Domestic': 103,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYXN',
#   'AirportName': 'WHALE COVE',
#   'Connections': 6,
#   'Departures': 753,
#   'Domestic': 753,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYFO',
#   'AirportName': 'FLIN FLON',
#   'Connections': 2,
#   'Departures': 615,
#   'Domestic': 615,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYTS',
#   'AirportName': 'TIMMINS',
#   'Connections': 4,
#   'Departures': 4750,
#   'Domestic': 4750,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYEK',
#   'AirportName': 'ESKIMO POINT',
#   'Connections': 5,
#   'Departures': 660,
#   'Domestic': 660,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYBK',
#   'AirportName': 'BAKER LAKE',
#   'Connections': 4,
#   'Departures': 705,
#   'Domestic': 705,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYRL',
#   'AirportName': 'RED LAKE',
#   'Connections': 10,
#   'Departures': 3022,
#   'Domestic': 3022,
#   'DomesticConnections': 10,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYQK',
#   'AirportName': 'KENORA',
#   'Connections': 2,
#   'Departures': 810,
#   'Domestic': 810,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYDQ',
#   'AirportName': 'DAWSON CREEK',
#   'Connections': 5,
#   'Departures': 264,
#   'Domestic': 264,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYVR',
#   'AirportName': 'VANCOUVER INTL',
#   'Connections': 179,
#   'Departures': 105079,
#   'Domestic': 72579,
#   'DomesticConnections': 78,
#   'International': 32500,
#   'InternationalConnections': 101,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2010},
#  {'Airport': 'CYDA',
#   'AirportName': 'DAWSON CITY',
#   'Connections': 3,
#   'Departures': 791,
#   'Domestic': 791,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYGK',
#   'AirportName': 'KINGSTON',
#   'Connections': 1,
#   'Departures': 1633,
#   'Domestic': 1633,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYUB',
#   'AirportName': 'TUKTOYAKTUK',
#   'Connections': 1,
#   'Departures': 937,
#   'Domestic': 937,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYPC',
#   'AirportName': 'PAULATUK',
#   'Connections': 1,
#   'Departures': 156,
#   'Domestic': 156,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYAM',
#   'AirportName': 'SAULT STE-MARIE',
#   'Connections': 6,
#   'Departures': 5396,
#   'Domestic': 5396,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYEV',
#   'AirportName': 'INUVIK',
#   'Connections': 13,
#   'Departures': 3309,
#   'Domestic': 3309,
#   'DomesticConnections': 13,
# ...
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYMX',
#   'AirportName': 'MIRABEL',
#   'Connections': 16,
#   'Departures': 2199,
#   'Domestic': 1249,
#   'DomesticConnections': 6,
#   'International': 950,
#   'InternationalConnections': 10,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYYB',
#   'AirportName': 'NORTH BAY',
#   'Connections': 4,
#   'Departures': 2040,
#   'Domestic': 2040,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYYL',
#   'AirportName': 'LYNN LAKE',
#   'Connections': 2,
#   'Departures': 262,
#   'Domestic': 262,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYFJ',
#   'AirportName': 'MONT TREMBLANT',
#   'Connections': 1,
#   'Departures': 38,
#   'Domestic': 0,
#   'DomesticConnections': 0,
#   'International': 38,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYPC',
#   'AirportName': 'PAULATUK',
#   'Connections': 2,
#   'Departures': 262,
#   'Domestic': 262,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CZMD',
#   'AirportName': 'MUSKRAT DAM',
#   'Connections': 1,
#   'Departures': 104,
#   'Domestic': 104,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYER',
#   'AirportName': 'FORT SEVERN',
#   'Connections': 3,
#   'Departures': 312,
#   'Domestic': 312,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2014},
#  {'Airport': 'CYPH',
#   'AirportName': 'INUKJUAK',
#   'Connections': 4,
#   'Departures': 959,
#   'Domestic': 959,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2010},
#  {'Airport': 'CYNE',
#   'AirportName': 'NORWAY HOUSE',
#   'Connections': 2,
#   'Departures': 444,
#   'Domestic': 444,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYUT',
#   'AirportName': 'REPULSE BAY',
#   'Connections': 6,
#   'Departures': 838,
#   'Domestic': 838,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYYU',
#   'AirportName': 'KAPUSKASING',
#   'Connections': 1,
#   'Departures': 1052,
#   'Domestic': 1052,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYEV',
#   'AirportName': 'INUVIK',
#   'Connections': 11,
#   'Departures': 2332,
#   'Domestic': 2332,
#   'DomesticConnections': 11,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYJT',
#   'AirportName': 'STEPHENVILLE',
#   'Connections': 4,
#   'Departures': 476,
#   'Domestic': 476,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYYU',
#   'AirportName': 'KAPUSKASING',
#   'Connections': 1,
#   'Departures': 664,
#   'Domestic': 664,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYCD',
#   'AirportName': 'NANAIMO ARPT',
#   'Connections': 3,
#   'Departures': 3895,
#   'Domestic': 3559,
#   'DomesticConnections': 2,
#   'International': 336,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYDQ',
#   'AirportName': 'DAWSON CREEK',
#   'Connections': 4,
#   'Departures': 315,
#   'Domestic': 315,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYLA',
#   'AirportName': 'AUPALUK',
#   'Connections': 3,
#   'Departures': 831,
#   'Domestic': 831,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2013},
#  {'Airport': 'CYNC',
#   'AirportName': 'WEMINDJI',
#   'Connections': 2,
#   'Departures': 618,
#   'Domestic': 618,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2010},
#  {'Airport': 'CYEV',
#   'AirportName': 'INUVIK',
#   'Connections': 14,
#   'Departures': 3809,
#   'Domestic': 3809,
#   'DomesticConnections': 14,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYMX',
#   'AirportName': 'MIRABEL',
#   'Connections': 27,
#   'Departures': 3294,
#   'Domestic': 1251,
#   'DomesticConnections': 7,
#   'International': 2043,
#   'InternationalConnections': 20,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYQD',
#   'AirportName': 'THE PAS',
#   'Connections': 4,
#   'Departures': 1523,
#   'Domestic': 1523,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYRB',
#   'AirportName': 'RESOLUTE',
#   'Connections': 5,
#   'Departures': 582,
#   'Domestic': 582,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYWK',
#   'AirportName': 'WABUSH',
#   'Connections': 10,
#   'Departures': 2446,
#   'Domestic': 2446,
#   'DomesticConnections': 10,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYPL',
#   'AirportName': 'PICKLE LAKE',
#   'Connections': 5,
#   'Departures': 1013,
#   'Domestic': 1013,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYQI',
#   'AirportName': 'YARMOUTH',
#   'Connections': 2,
#   'Departures': 876,
#   'Domestic': 438,
#   'DomesticConnections': 1,
#   'International': 438,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYYB',
#   'AirportName': 'NORTH BAY',
#   'Connections': 4,
#   'Departures': 2171,
#   'Domestic': 2171,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYAT',
#   'AirportName': 'ATTAWAPISKAT',
#   'Connections': 3,
#   'Departures': 571,
#   'Domestic': 571,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYBB',
#   'AirportName': 'KUGAARUK',
#   'Connections': 7,
#   'Departures': 446,
#   'Domestic': 446,
#   'DomesticConnections': 7,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2015},
#  {'Airport': 'CYXY',
#   'AirportName': 'WHITEHORSE',
#   'Connections': 8,
#   'Departures': 2565,
#   'Domestic': 2531,
#   'DomesticConnections': 6,
#   'International': 34,
#   'InternationalConnections': 2,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYMH',
#   'AirportName': "MARY'S HARBOUR",
#   'Connections': 2,
#   'Departures': 10,
#   'Domestic': 10,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYGX',
#   'AirportName': 'GILLAM',
#   'Connections': 2,
#   'Departures': 261,
#   'Domestic': 261,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYLL',
#   'AirportName': 'LLOYDMINSTER',
#   'Connections': 2,
#   'Departures': 556,
#   'Domestic': 556,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYYE',
#   'AirportName': 'FORT NELSON',
#   'Connections': 2,
#   'Departures': 855,
#   'Domestic': 855,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYYB',
#   'AirportName': 'NORTH BAY',
#   'Connections': 5,
#   'Departures': 2686,
#   'Domestic': 2686,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYPE',
#   'AirportName': 'PEACE RIVER',
#   'Connections': 1,
#   'Departures': 35,
#   'Domestic': 35,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYSK',
#   'AirportName': 'SANIKILUAQ',
#   'Connections': 4,
#   'Departures': 209,
#   'Domestic': 209,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYDF',
#   'AirportName': 'DEER LAKE',
#   'Connections': 19,
#   'Departures': 4946,
#   'Domestic': 4946,
#   'DomesticConnections': 19,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYXD',
#   'AirportName': 'MUNICIPAL',
#   'Connections': 1,
#   'Departures': 261,
#   'Domestic': 261,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CZMD',
#   'AirportName': 'MUSKRAT DAM',
#   'Connections': 4,
#   'Departures': 966,
#   'Domestic': 966,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2013},
#  {'Airport': 'CZFN',
#   'AirportName': 'FORT NORMAN',
#   'Connections': 2,
#   'Departures': 1300,
#   'Domestic': 1300,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYLL',
#   'AirportName': 'LLOYDMINSTER',
#   'Connections': 2,
#   'Departures': 557,
#   'Domestic': 557,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CYMO',
#   'AirportName': 'MOOSONEE',
#   'Connections': 3,
#   'Departures': 1364,
#   'Domestic': 1364,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYXJ',
#   'AirportName': 'FORT ST JOHN',
#   'Connections': 5,
#   'Departures': 2786,
#   'Domestic': 2786,
#   'DomesticConnections': 5,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2011},
#  {'Airport': 'CYHY',
#   'AirportName': 'HAY RIVER',
#   'Connections': 4,
#   'Departures': 1126,
#   'Domestic': 1126,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CZPB',
#   'AirportName': 'SACHIGO LAKE',
#   'Connections': 7,
#   'Departures': 411,
#   'Domestic': 411,
#   'DomesticConnections': 7,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CZUM',
#   'AirportName': 'CHURCHILL FALLS',
#   'Connections': 3,
#   'Departures': 567,
#   'Domestic': 567,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2018},
#  {'Airport': 'CYLY',
#   'AirportName': 'LYTTON',
#   'Connections': 1,
#   'Departures': 122,
#   'Domestic': 122,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYKD',
#   'AirportName': 'AKLAVIK',
#   'Connections': 1,
#   'Departures': 503,
#   'Domestic': 503,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2012},
#  {'Airport': 'CYGO',
#   'AirportName': 'GODS NARROWS',
#   'Connections': 4,
#   'Departures': 155,
#   'Domestic': 155,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYXP',
#   'AirportName': 'PANGNIRTUNG',
#   'Connections': 6,
#   'Departures': 1896,
#   'Domestic': 1896,
#   'DomesticConnections': 6,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2009},
#  {'Airport': 'CYJQ',
#   'AirportName': 'BELLA BELLA',
#   'Connections': 4,
#   'Departures': 1180,
#   'Domestic': 1180,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2014},
#  {'Airport': 'CYBL',
#   'AirportName': 'CAMPBELL RIVER',
#   'Connections': 7,
#   'Departures': 4327,
#   'Domestic': 4052,
#   'DomesticConnections': 6,
#   'International': 275,
#   'InternationalConnections': 1,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005},
#  {'Airport': 'CYNC',
#   'AirportName': 'WEMINDJI',
#   'Connections': 2,
#   'Departures': 720,
#   'Domestic': 720,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2012},
#  {'Airport': 'CYHK',
#   'AirportName': 'GJOA HAVEN',
#   'Connections': 11,
#   'Departures': 1046,
#   'Domestic': 1046,
#   'DomesticConnections': 11,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYSK',
#   'AirportName': 'SANIKILUAQ',
#   'Connections': 2,
#   'Departures': 209,
#   'Domestic': 209,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CYWG',
#   'AirportName': 'WINNIPEG JAMES ARMSTRONG RICHARDSON  INTL',
#   'Connections': 83,
#   'Departures': 31295,
#   'Domestic': 26143,
#   'DomesticConnections': 63,
#   'International': 5152,
#   'InternationalConnections': 20,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2004},
#  {'Airport': 'CZFM',
#   'AirportName': 'FORT MCPHERSON',
#   'Connections': 1,
#   'Departures': 470,
#   'Domestic': 470,
#   'DomesticConnections': 1,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2016},
#  {'Airport': 'CYCB',
#   'AirportName': 'CAMBRIDGE BAY',
#   'Connections': 13,
#   'Departures': 1394,
#   'Domestic': 1394,
#   'DomesticConnections': 13,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2003},
#  {'Airport': 'CZUM',
#   'AirportName': 'CHURCHILL FALLS',
#   'Connections': 4,
#   'Departures': 565,
#   'Domestic': 565,
#   'DomesticConnections': 4,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2017},
#  {'Airport': 'CYFT',
#   'AirportName': 'MAKKOVIK',
#   'Connections': 2,
#   'Departures': 576,
#   'Domestic': 576,
#   'DomesticConnections': 2,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2008},
#  {'Airport': 'CYYE',
#   'AirportName': 'FORT NELSON',
#   'Connections': 3,
#   'Departures': 812,
#   'Domestic': 812,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2006},
#  {'Airport': 'CYPL',
#   'AirportName': 'PICKLE LAKE',
#   'Connections': 7,
#   'Departures': 480,
#   'Domestic': 480,
#   'DomesticConnections': 7,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2007},
#  {'Airport': 'CYLA',
#   'AirportName': 'AUPALUK',
#   'Connections': 3,
#   'Departures': 741,
#   'Domestic': 741,
#   'DomesticConnections': 3,
#   'International': 0,
#   'InternationalConnections': 0,
#   'Name': 'Canada',
#   'State': 'CAN',
#   'Year': 2005}]

# %%
len(data)
# Out:
# 3165

# %%
connections = []
departures = []
name = []
year = []

for i in range(len(data)):
    connections.append(data[i]["Connections"])
    departures.append(data[i]["Departures"])
    name.append(data[i]["AirportName"])
    year.append(data[i]["Year"])

# %%
year
# Out:
# [2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2008,
#  2018,
#  2018,
#  2017,
#  2018,
#  2018,
#  2004,
#  2018,
#  2007,
#  2018,
#  2018,
#  2003,
#  2016,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2012,
#  2018,
#  2009,
#  2006,
#  2018,
#  2018,
#  2014,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2011,
#  2018,
#  2015,
#  2004,
#  2018,
#  2018,
#  2014,
#  2018,
#  2018,
#  2018,
#  2007,
#  2009,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2006,
#  2018,
#  2005,
#  2018,
#  2008,
#  2018,
#  2018,
#  2018,
#  2015,
#  2018,
#  2018,
#  2018,
#  2017,
#  2017,
#  2017,
#  2005,
#  2006,
#  2008,
#  2011,
#  2017,
#  2012,
#  2017,
#  2018,
#  2006,
#  2008,
#  2012,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2016,
#  2017,
#  2003,
#  2005,
#  2013,
#  2016,
#  2017,
#  2006,
#  2007,
#  2010,
#  2017,
#  2008,
#  2017,
#  2017,
#  2007,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2010,
#  2017,
#  2017,
#  2015,
#  2017,
#  2017,
#  2017,
#  2006,
#  2017,
#  2017,
#  2016,
#  2017,
#  2017,
#  2007,
#  2017,
#  2017,
#  2008,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2010,
#  2017,
#  2004,
#  2017,
#  2017,
#  2011,
#  2017,
#  2017,
#  2017,
#  2003,
#  2017,
#  2017,
#  2011,
#  2011,
#  2017,
#  2018,
#  2013,
#  2018,
#  2017,
#  2010,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2004,
#  2017,
#  2017,
#  2013,
#  2017,
#  2003,
#  2017,
#  2018,
#  2017,
#  2017,
#  2017,
#  2010,
#  2014,
#  2017,
#  2017,
#  2006,
#  2017,
#  2011,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2017,
#  2017,
#  2005,
#  2017,
#  2017,
#  2017,
#  2007,
#  2017,
#  2008,
#  2007,
#  2017,
#  2017,
#  2017,
#  2017,
#  2015,
#  2017,
#  2013,
#  2006,
#  2017,
#  2018,
#  2008,
#  2017,
#  2017,
#  2017,
#  2004,
#  2017,
#  2004,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2016,
#  2016,
#  2016,
#  2004,
#  2016,
#  2016,
#  2004,
#  2017,
#  2004,
#  2007,
#  2016,
#  2016,
#  2018,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2017,
#  2016,
#  2014,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2012,
#  2017,
#  2016,
#  2016,
#  2010,
#  2016,
#  2016,
#  2016,
#  2005,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2011,
#  2016,
#  2016,
#  2016,
#  2003,
#  2016,
#  2011,
#  2016,
#  2016,
#  2009,
#  2018,
#  2010,
#  2016,
#  2012,
#  2016,
#  2009,
#  2016,
#  2016,
#  2009,
#  2016,
#  2016,
#  2013,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2013,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  2013,
#  2016,
#  2016,
#  2016,
#  2016,
#  2004,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2018,
#  2016,
#  2016,
#  2013,
#  2018,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2012,
#  2009,
#  2016,
#  2016,
#  2016,
#  2016,
#  2008,
#  2016,
#  2012,
#  2016,
#  2016,
#  2017,
#  2013,
#  2016,
#  2007,
#  2016,
#  2013,
#  2016,
#  2010,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2004,
#  2016,
#  2007,
#  2016,
#  2016,
#  2017,
#  2004,
#  2015,
#  2008,
#  2015,
#  2003,
#  2011,
#  2015,
#  2015,
#  2006,
#  2015,
#  2015,
#  2015,
#  2015,
#  2017,
#  2015,
#  2015,
#  2015,
#  2009,
#  2011,
#  2015,
#  2012,
#  2014,
#  2015,
#  2015,
#  2015,
#  2015,
#  2017,
#  2015,
#  2015,
#  2015,
#  2018,
#  2015,
#  2014,
#  2016,
#  2006,
#  2015,
#  2005,
#  2015,
#  2015,
#  2015,
#  2017,
#  2012,
#  2015,
#  2004,
#  2016,
#  2009,
#  2015,
#  2013,
#  2015,
#  2018,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2012,
#  2017,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2008,
#  2007,
#  2015,
#  2004,
#  2017,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2012,
#  2015,
#  2013,
#  2015,
#  2006,
#  2015,
#  2011,
#  2015,
#  2015,
#  2009,
#  2015,
#  2015,
#  2017,
#  2013,
#  2015,
#  2012,
#  2015,
#  2015,
#  2016,
#  2017,
#  2015,
#  2015,
#  2007,
#  2015,
#  2016,
#  2015,
#  2015,
#  2015,
#  2014,
#  2015,
#  2016,
#  2015,
#  2018,
#  2006,
#  2015,
#  2015,
#  2015,
#  2015,
#  2004,
#  2015,
#  2012,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2014,
#  2015,
#  2015,
#  2015,
#  2015,
#  2008,
#  2012,
#  2015,
#  2015,
#  2018,
#  2016,
#  2005,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2014,
#  2014,
#  2006,
#  2014,
#  2014,
#  2017,
#  2015,
#  2014,
#  2004,
#  2017,
#  2003,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2004,
#  2018,
#  2010,
#  2014,
#  2014,
#  2014,
#  2014,
#  2010,
#  2014,
#  2018,
#  2013,
#  2013,
#  2016,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2018,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2004,
#  2018,
#  2014,
#  2014,
#  2005,
#  2014,
#  2015,
#  2014,
#  2014,
#  2018,
#  2014,
#  2011,
#  2014,
#  2014,
#  2014,
#  2014,
#  2016,
#  2014,
#  2014,
#  2006,
#  2016,
#  2007,
#  2014,
#  2014,
#  2011,
#  2007,
#  2016,
#  2017,
#  2017,
#  2014,
#  2014,
#  2014,
#  2014,
#  2004,
#  2014,
#  2014,
#  2014,
#  2016,
#  2014,
#  2017,
#  2009,
#  2014,
#  2004,
#  2018,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2016,
#  2004,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2010,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2017,
#  2014,
#  2017,
#  2014,
#  2014,
#  2014,
#  2017,
#  2014,
#  2018,
#  2012,
#  2007,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2018,
#  2005,
#  2014,
#  2013,
#  2013,
#  2008,
#  2016,
#  2009,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2016,
#  2013,
#  2013,
#  2013,
#  2005,
#  2013,
#  2013,
#  2017,
#  2006,
#  2017,
#  2006,
#  2015,
#  2017,
#  2013,
#  2004,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2015,
#  2011,
#  2013,
#  2013,
#  2005,
#  2007,
#  2016,
#  2008,
#  2013,
#  2007,
#  2013,
#  2015,
#  2013,
#  2013,
#  2013,
#  2016,
#  2017,
#  2013,
#  2013,
#  2014,
#  2013,
#  2015,
#  2013,
#  2006,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2014,
#  2003,
#  2013,
#  2011,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2006,
#  2016,
#  2013,
#  2007,
#  2007,
#  2013,
#  2013,
#  2016,
#  2013,
#  2013,
#  2013,
#  2003,
#  2013,
#  2013,
#  2010,
#  2017,
#  2016,
#  2008,
#  2016,
#  2013,
#  2005,
#  2010,
#  2015,
#  2011,
#  2013,
#  2007,
#  2008,
#  2013,
#  2017,
#  2014,
#  2013,
#  2008,
#  2012,
#  2013,
#  2017,
#  2013,
#  2013,
#  2013,
#  2018,
#  2015,
#  2013,
#  2013,
#  2013,
#  2009,
#  2017,
#  2015,
#  2013,
#  2013,
#  2013,
#  2015,
#  2013,
#  2010,
#  2013,
#  2007,
#  2013,
#  2006,
#  2018,
#  2013,
#  2013,
#  2010,
#  2015,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2014,
#  2017,
#  2013,
#  2003,
#  2015,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2014,
#  2007,
#  2013,
#  2014,
#  2013,
#  2005,
#  2009,
#  2017,
#  2013,
#  2015,
#  2013,
#  2018,
#  2013,
#  2013,
#  2014,
#  2013,
#  2005,
#  2015,
#  2007,
#  2013,
#  2015,
#  2013,
#  2013,
#  2013,
#  2012,
#  2012,
#  2012,
#  2003,
#  2018,
#  2017,
#  2016,
#  2011,
#  2012,
#  2012,
#  2007,
#  2012,
#  2007,
#  2012,
#  2004,
#  2012,
#  2009,
#  2012,
#  2017,
#  2012,
#  2013,
#  2012,
#  2015,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2006,
#  2012,
#  2012,
#  2012,
#  2006,
#  2010,
#  2012,
#  2018,
#  2012,
#  2011,
#  2012,
#  2018,
#  2018,
#  2016,
#  2004,
#  2014,
#  2012,
#  2012,
#  2017,
#  2014,
#  2011,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2004,
#  2014,
#  2012,
#  2007,
#  2012,
#  2012,
#  2015,
#  2012,
#  2012,
#  2007,
#  2012,
#  2012,
#  2012,
#  2016,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2006,
#  2008,
#  2012,
#  2012,
#  2012,
#  2012,
#  2015,
#  2012,
#  2013,
#  2009,
#  2013,
#  2015,
#  2012,
#  2007,
#  2016,
#  2015,
#  2005,
#  2012,
#  2013,
#  2014,
#  2006,
#  2006,
#  2012,
#  2012,
#  2017,
#  2006,
#  2012,
#  2014,
#  2012,
#  2015,
#  2010,
#  2012,
#  2012,
#  2014,
#  2012,
#  2012,
#  2010,
#  2012,
#  2012,
#  2015,
#  2016,
#  2012,
#  2012,
#  2014,
#  2018,
#  2018,
#  2012,
#  2009,
#  2012,
#  2016,
#  2010,
#  2012,
#  2012,
#  2017,
#  2012,
#  2012,
#  2006,
#  2012,
#  2005,
#  2012,
#  2004,
#  2008,
#  2012,
#  2017,
#  2016,
#  2016,
#  2006,
#  2012,
#  2015,
#  2012,
#  2014,
#  ...]

# %%
new_df = pd.DataFrame({"AirportName" : name, "Number of Departures" : departures, "Number of Connections" : connections, "Year" : year })
new_df.to_csv()
# Out:
#                                     AirportName  Number of Departures  \
# 3145                                  HAY RIVER                  1126
# 3146                               SACHIGO LAKE                   411
# 3147                            CHURCHILL FALLS                   567
# 3148                                     LYTTON                   122
# 3149                                    AKLAVIK                   503
# 3150                               GODS NARROWS                   155
# 3151                                PANGNIRTUNG                  1896
# 3152                                BELLA BELLA                  1180
# 3153                             CAMPBELL RIVER                  4327
# 3154                                   WEMINDJI                   720
# 3155                                 GJOA HAVEN                  1046
# 3156                                 SANIKILUAQ                   209
# 3157  WINNIPEG JAMES ARMSTRONG RICHARDSON  INTL                 31295
# 3158                             FORT MCPHERSON                   470
# 3159                              CAMBRIDGE BAY                  1394
# 3160                            CHURCHILL FALLS                   565
# 3161                                   MAKKOVIK                   576
# 3162                                FORT NELSON                   812
# 3163                                PICKLE LAKE                   480
# 3164                                    AUPALUK                   741
#
#       Number of Connections  Year
# 3145                      4  2003
# 3146                      7  2004
# 3147                      3  2018
# 3148                      1  2006
# 3149                      1  2012
# 3150                      4  2009
# 3151                      6  2009
# 3152                      4  2014
# 3153                      7  2005
# 3154                      2  2012
# 3155                     11  2003
# 3156                      2  2003
# 3157                     83  2004
# 3158                      1  2016
# 3159                     13  2003
# 3160                      4  2017
# 3161                      2  2008
# 3162                      3  2006
# 3163                      7  2007
# 3164                      3  2005
